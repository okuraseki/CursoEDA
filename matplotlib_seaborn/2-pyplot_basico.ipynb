# %% [markdown]
# ## Pyplot
# ### Es una herramienta que tiene matplotlib, para diseñar y ejecutar graficas de manera sencilla.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,5,11)

y = x**2

# %% [markdown]
# - plt.plot(x, y)  Define la x y la y a la hora de dibujar la grafica, lo que tomara como x e y
# - plt.show() Dibuja la grafica

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y, 'ro-') 
# Definimos el color con la primera r rojo, b blue, etc..
# el segundo caracter s square , 0 cirulo, x dibuja x
# - une los puntos
# : linea punteada
plt.show()

# %%
plt.hist(x)
plt.show()

# %%
plt.pie(x)
plt.show()

# %%
plt.scatter(x,y)
plt.show()

# %%
plt.boxplot(x)
plt.show()
