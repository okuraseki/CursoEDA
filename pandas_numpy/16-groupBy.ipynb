# %%
import pandas as pd

# %%
df_books = pd.read_csv('./data/bestsellers-with-categories_e591527f-ae45-4fa5-b0d1-d50142128fa6.csv', sep=',',header=0)
df_books.head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year        Genre
# 0  2016  Non Fiction
# 1  2011      Fiction

# %% [markdown]
# ### Similar al groupBy de SQL

# %%
df_books.groupby('Author').count()  # agrupamos y contamos cuantos registro de cada author
# Out:
#                             Name  User Rating  Reviews  Price  Year  Genre
# Author
# Abraham Verghese               2            2        2      2     2      2
# Adam Gasiewski                 1            1        1      1     1      1
# Adam Mansbach                  1            1        1      1     1      1
# Adir Levy                      1            1        1      1     1      1
# Admiral William H. McRaven     1            1        1      1     1      1
# ...                          ...          ...      ...    ...   ...    ...
# Walter Isaacson                3            3        3      3     3      3
# William Davis                  2            2        2      2     2      2
# William P. Young               2            2        2      2     2      2
# Wizards RPG Team               3            3        3      3     3      3
# Zhi Gang Sha                   2            2        2      2     2      2
#
# [248 rows x 6 columns]

# %%
# .sum()  .mean() .min() .max() etc hace sobre las columnas de los registro agrupados
df_books.groupby('Author').max()
# Out:
#                                                                          Name  \
# Author
# Abraham Verghese                                            Cutting for Stone
# Adam Gasiewski              Milk and Vine: Inspirational Quotes From Class...
# Adam Mansbach                                            Go the F**k to Sleep
# Adir Levy                   What Should Danny Do? (The Power to Choose Ser...
# Admiral William H. McRaven  Make Your Bed: Little Things That Can Change Y...
# ...                                                                       ...
# Walter Isaacson                                                    Steve Jobs
# William Davis               Wheat Belly: Lose the Wheat, Lose the Weight, ...
# William P. Young                  The Shack: Where Tragedy Confronts Eternity
# Wizards RPG Team                       Player's Handbook (Dungeons & Dragons)
# Zhi Gang Sha                Soul Healing Miracles: Ancient and New Sacred ...
#
# ...

# %%
# aqui nos muestra de cada author, los valores maximos de cada columna, si tienen varios registros, toma el mayor de entre ellos

# %% [markdown]
# #### Al hacer groupBy, el autor pasa ha ser el indice de cada row. por lo tanto se puede hacer loc de el nombre de dicho autor

# %%
df_books.groupby('Author').sum().loc['William Davis']  # acumula los valores para el autor
# Out:
# Name           Wheat Belly: Lose the Wheat, Lose the Weight, ...
# User Rating                                                  8.8
# Reviews                                                    14994
# Price                                                         12
# Year                                                        4025
# Genre                                     Non FictionNon Fiction
# Name: William Davis, dtype: object

# %%
# se puede usar el metodo reset_index() para que genere indices numericos standard y autor pase a ser una columna
df_books.groupby('Author').max().reset_index()
# Out:
#                          Author  \
# 0              Abraham Verghese
# 1                Adam Gasiewski
# 2                 Adam Mansbach
# 3                     Adir Levy
# 4    Admiral William H. McRaven
# ..                          ...
# 243             Walter Isaacson
# 244               William Davis
# 245            William P. Young
# 246            Wizards RPG Team
# 247                Zhi Gang Sha
#
#                                                   Name  User Rating  Reviews  \
# 0                                    Cutting for Stone          4.6     4866
# 1    Milk and Vine: Inspirational Quotes From Class...          4.4     3113
# 2                                 Go the F**k to Sleep          4.8     9568
# 3    What Should Danny Do? (The Power to Choose Ser...          4.8     8170
# 4    Make Your Bed: Little Things That Can Change Y...          4.7    10199
# ..                                                 ...          ...      ...
# ...

# %% [markdown]
# ## groupBy().agg()
#     - En agg se le especifican las funciones de agregacion que quieras
#     - ['min','max']

# %%
# genera una columna  por cada funcion de agregacion que le indiquemos asociada a cada columna
# en este caso min y max
df_books.groupby('Author').agg(['min','max'])
# Out:
#                                                                          Name  \
#                                                                           min
# Author
# Abraham Verghese                                            Cutting for Stone
# Adam Gasiewski              Milk and Vine: Inspirational Quotes From Class...
# Adam Mansbach                                            Go the F**k to Sleep
# Adir Levy                   What Should Danny Do? (The Power to Choose Ser...
# Admiral William H. McRaven  Make Your Bed: Little Things That Can Change Y...
# ...                                                                       ...
# Walter Isaacson                                             Leonardo da Vinci
# William Davis               Wheat Belly: Lose the Wheat, Lose the Weight, ...
# William P. Young                  The Shack: Where Tragedy Confronts Eternity
# Wizards RPG Team                       Player's Handbook (Dungeons & Dragons)
# ...

# %% [markdown]
# ### agg()
#     - Acepta en forma de diccionario los nombre de las columnas como key y las funciones de agregacion como value
#     - Se puede especificar cualquer numero de keys(columnas) , values(funciones)

# %%
df_books.groupby('Author').agg({'Reviews':['mean','max'], 'User Rating':'max'})
# Out:
#                                  Reviews        User Rating
#                                     mean    max         max
# Author
# Abraham Verghese             4866.000000   4866         4.6
# Adam Gasiewski               3113.000000   3113         4.4
# Adam Mansbach                9568.000000   9568         4.8
# Adir Levy                    8170.000000   8170         4.8
# Admiral William H. McRaven  10199.000000  10199         4.7
# ...                                  ...    ...         ...
# Walter Isaacson              6222.666667   7827         4.6
# William Davis                7497.000000   7497         4.4
# William P. Young            19720.000000  19720         4.6
# Wizards RPG Team            16990.000000  16990         4.8
# Zhi Gang Sha                  128.500000    220         4.6
#
# [248 rows x 3 columns]

# %%
df_books.groupby(['Author','Year']).count()
# Al pasar una lista con los label de las columnas los subagrupa
# Out:
#                        Name  User Rating  Reviews  Price  Genre
# Author           Year
# Abraham Verghese 2010     1            1        1      1      1
#                  2011     1            1        1      1      1
# Adam Gasiewski   2017     1            1        1      1      1
# Adam Mansbach    2011     1            1        1      1      1
# Adir Levy        2019     1            1        1      1      1
# ...                     ...          ...      ...    ...    ...
# Wizards RPG Team 2017     1            1        1      1      1
#                  2018     1            1        1      1      1
#                  2019     1            1        1      1      1
# Zhi Gang Sha     2009     1            1        1      1      1
#                  2013     1            1        1      1      1
#
# [493 rows x 5 columns]
