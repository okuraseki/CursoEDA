# %%
import pandas as pd

# %%
df_books = pd.read_csv('./data/bestsellers-with-categories_e591527f-ae45-4fa5-b0d1-d50142128fa6.csv', sep=',',header=0)
df_books.head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year        Genre
# 0  2016  Non Fiction
# 1  2011      Fiction

# %% [markdown]
# ### info()
#     - Informacion sobre el numero de registros, los nulos, el tipo de dato de cada columna, etc

# %%
# head()  trae los n primeros registros

# info() informacion detallada

df_books.info() # mucha informacion acerca del DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         550 non-null    object
#  1   Author       550 non-null    object
#  2   User Rating  550 non-null    float64
#  3   Reviews      550 non-null    int64
#  4   Price        550 non-null    int64
#  5   Year         550 non-null    int64
#  6   Genre        550 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 30.2+ KB

# %% [markdown]
# ### describe()
#  - Informacino estadistica de las columnas numéricas

# %%
df_books.describe()

# Entrega datos estadisticos de las columnas numericas, cantidad, media, min ,max, percentiles
# Out:
#        User Rating       Reviews       Price         Year
# count   550.000000    550.000000  550.000000   550.000000
# mean      4.618364  11953.281818   13.100000  2014.000000
# std       0.226980  11731.132017   10.842262     3.165156
# min       3.300000     37.000000    0.000000  2009.000000
# 25%       4.500000   4058.000000    7.000000  2011.000000
# 50%       4.700000   8580.000000   11.000000  2014.000000
# 75%       4.800000  17253.250000   16.000000  2017.000000
# max       4.900000  87841.000000  105.000000  2019.000000

# %% [markdown]
# ### tail()
#     - Es como head() pero devuelve los registros dados por la cola
#
# ### head()

# %%
df_books.tail(3)
# Out:
#                                                   Name       Author  \
# 547  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 548  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 549  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
#
#      User Rating  Reviews  Price  Year        Genre
# 547          4.7    14331      8  2017  Non Fiction
# 548          4.7    14331      8  2018  Non Fiction
# 549          4.7    14331      8  2019  Non Fiction

# %% [markdown]
# ### memory_usage(deep=True)
#     - Cuanta memoria estamos usando en el DataFrame, por cada columna

# %%
df_books.memory_usage(deep=True)
# Out:
# Index            132
# Name           59737
# Author         39078
# User Rating     4400
# Reviews         4400
# Price           4400
# Year            4400
# Genre          36440
# dtype: int64

# %% [markdown]
# ### .value_counts()
#     - Cuenta cuantas veces repetidas esta en todos los registros.

# %%
df_books['Author'].value_counts()
# Out:
# Author
# Jeff Kinney                           12
# Rick Riordan                          11
# Suzanne Collins                       11
# Gary Chapman                          11
# American Psychological Association    10
#                                       ..
# Geneen Roth                            1
# Alan Moore                             1
# Sara Gruen                             1
# Hillary Rodham Clinton                 1
# Randall Munroe                         1
# Name: count, Length: 248, dtype: int64

# %% [markdown]
# ### drop_duplicates()
#     - Elimina los duplicados

# %%
#pd.concat([df_books,df_books])  # estamos agregando el registro [0] al dataFrame
# ahora tendremos ese registro duplicado
df_books = pd.concat([df_books,df_books.loc[0:0]])

# %%
df_books  # aqui tenemos el primer registro duplicado
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
# 0                        10-Day Green Smoothie Cleanse
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
df_books.drop_duplicates()  # keep='last'  mantiene el ultimo encontrado y borra los anteriores duplicados
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %% [markdown]
# ### sort_values()
#     - Se le especifica una columna para que ordene por esa
#     - ascending = False/True

# %%
df_books.sort_values('Year', ascending=False)
# Out:
#                                                   Name  \
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
# 380  The Four Agreements: A Practical Guide to Pers...
# 155  Harry Potter and the Goblet of Fire: The Illus...
# 145                                     Goodnight Moon
# ..                                                 ...
# 95                            Eclipse (Twilight Sagas)
# 96                                  Eclipse (Twilight)
# 459        The Shack: Where Tragedy Confronts Eternity
# 470                           The Time Traveler's Wife
# 520                            Under the Dome: A Novel
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 4    National Geographic Kids          4.8     7665     12  2019  Non Fiction
# 549               Jen Sincero          4.7    14331      8  2019  Non Fiction
# ...
