# %%
import pandas as pd 
import altair as alt

# %%
chicago_data = './data/Traffic_Crashes1.csv'
df_chicago = pd.read_csv(chicago_data)

# %%
df_chicago['CRASH_DATE_time'] = df_chicago['CRASH_DATE'].apply(lambda x : pd.to_datetime(x, errors='coerce', utc=True))

# %%
df_chicago.head()
# Out:
#    Unnamed: 0                                    CRASH_RECORD_ID     RD_NO  \
# 0      290702  9e97e92753166de921a0e87199513aa841142c6fbb3a1e...  JA154528
# 1      405524  e5fe82ab7757d630a7f79927113bc63b5bede0cda74665...  JC391213
# 2      261834  8c8ea6db9e1950765419429e2732ba5598fc6f87ac9e0c...  JC273287
# 3       38519  02671b7d36a9d189d607778816fec23bbb2e5ac3cd3039...  JA307115
# 4      420197  ef1b1d450f65c6d16245dffdd3304d93b8be7d7bbf47f3...  JB247942
#
#   CRASH_DATE_EST_I           CRASH_DATE  POSTED_SPEED_LIMIT  \
# 0              NaN  2017-02-14 10:00:00                  30
# 1              NaN  2019-08-13 19:12:00                  35
# 2              NaN  2019-05-22 08:30:00                  25
# 3              NaN  2017-06-14 16:50:00                   0
# 4              NaN  2018-05-03 08:35:00                  30
#
#   TRAFFIC_CONTROL_DEVICE      DEVICE_CONDITION WEATHER_CONDITION  \
# 0            NO CONTROLS           NO CONTROLS             CLEAR
# ...

# %%
# Uso de groupBy

report_1 = df_chicago.groupby(['LIGHTING_CONDITION','REPORT_TYPE','CRASH_HOUR']).agg({'NUM_UNITS':'sum'})

# %%
report_1
# Out:
#                                                           NUM_UNITS
# LIGHTING_CONDITION REPORT_TYPE                CRASH_HOUR
# DARKNESS           AMENDED                    20                  2
#                    NOT ON SCENE (DESK REPORT) 0                  97
#                                               1                  86
#                                               2                  64
#                                               3                  57
# ...                                                             ...
# UNKNOWN            ON SCENE                   19                  9
#                                               20                 10
#                                               21                 10
#                                               22                 20
#                                               23                  6
#
# [291 rows x 1 columns]

# %%
report_1 = report_1.reset_index() # para generar los indices

# %%
report_1
# Out:
#     LIGHTING_CONDITION                 REPORT_TYPE  CRASH_HOUR  NUM_UNITS
# 0             DARKNESS                     AMENDED          20          2
# 1             DARKNESS  NOT ON SCENE (DESK REPORT)           0         97
# 2             DARKNESS  NOT ON SCENE (DESK REPORT)           1         86
# 3             DARKNESS  NOT ON SCENE (DESK REPORT)           2         64
# 4             DARKNESS  NOT ON SCENE (DESK REPORT)           3         57
# ..                 ...                         ...         ...        ...
# 286            UNKNOWN                    ON SCENE          19          9
# 287            UNKNOWN                    ON SCENE          20         10
# 288            UNKNOWN                    ON SCENE          21         10
# 289            UNKNOWN                    ON SCENE          22         20
# 290            UNKNOWN                    ON SCENE          23          6
#
# [291 rows x 4 columns]

# %%
# Graficos
alt.Chart(report_1).mark_bar().encode(x='LIGHTING_CONDITION',y='NUM_UNITS',color='REPORT_TYPE').properties(width=220)
# Out:
# alt.Chart(...)

# %%
# Varias funciones de agregacion sobre un mismo groupby
report_1 = df_chicago.groupby(['LIGHTING_CONDITION','REPORT_TYPE','CRASH_HOUR']).agg({'NUM_UNITS':['sum','min','max']})

# %%
report_1
# Out:
#                                                          NUM_UNITS
#                                                                sum min max
# LIGHTING_CONDITION REPORT_TYPE                CRASH_HOUR
# DARKNESS           AMENDED                    20                 2   2   2
#                    NOT ON SCENE (DESK REPORT) 0                 97   1   2
#                                               1                 86   1   2
#                                               2                 64   1   5
#                                               3                 57   1   2
# ...                                                            ...  ..  ..
# UNKNOWN            ON SCENE                   19                 9   1   2
#                                               20                10   2   2
#                                               21                10   2   2
#                                               22                20   2   3
# ...
